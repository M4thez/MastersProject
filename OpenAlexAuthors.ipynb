# %% [markdown]
# # This notebook fetches all the EUNICoast authors from OpenAlex

# %%
from pyalex import config, Authors
import helpers
import time
from itertools import chain
import pandas as pd
import pyarrow  # engine for parquet

# %%
# Email Configuration for the polite pool
config.email = "bm57596@zut.edu.pl"

# Configuration for retrying requests
config.max_retries = 3
config.retry_backoff_factor = 0.5  # delay between two retries
config.retry_https_codes = [429, 500, 503]

universities_ror_url = {
    # West Pomeranian University of Technology in Szczecin
    'PL_ZUT': 'https://ror.org/0596m7f19',
    # Burgas Free University
    'BG_BFU': 'https://ror.org/02ek1bx64',
    # University of Patras
    'GR_UOP': 'https://ror.org/017wvtq80',
    # University of Dubrovnik
    'HR_UNIDU': 'https://ror.org/05yptqp13',
    # University EMUNI
    'SL_EMUNI': 'https://ror.org/03761pf32',
    # University of Sassari
    'IT_UNISS': 'https://ror.org/01bnjbv91',
    # University of the Antilles
    'FR_UAG': 'https://ror.org/02ryfmr77',
    # University of the Azores
    'PT_UAC': 'https://ror.org/04276xd64',
    # University of the Balearic Islands
    'ES_UIB': 'https://ror.org/03e10x626',
    # University Le Havre Normandie
    'FR_ULHN': 'https://ror.org/05v509s40',
    # University of the Faroe Islands
    'FO_UF': 'https://ror.org/05mwmd090',
    # Stralsund University of Applied Sciences
    'DE_HOCHSTRALSUND': 'https://ror.org/04g99jx54',
    # Åland University of Applied Sciences
    'FI_AUAS': 'https://ror.org/05mknbx32',
}

# Just ROR IDs stored in universities_ror_id dictionary
universities_ror_id = {}
for key in universities_ror_url:
    universities_ror_id[key] = helpers.extract_id_from_url(
        universities_ror_url[key])

print(universities_ror_id)
# Out:
# {'PL_ZUT': '0596m7f19', 'BG_BFU': '02ek1bx64', 'GR_UOP': '017wvtq80', 'HR_UNIDU': '05yptqp13', 'SL_EMUNI': '03761pf32', 'IT_UNISS': '01bnjbv91', 'FR_UAG': '02ryfmr77', 'PT_UAC': '04276xd64', 'ES_UIB': '03e10x626', 'FR_ULHN': '05v509s40', 'FO_UF': '05mwmd090', 'DE_HOCHSTRALSUND': '04g99jx54', 'FI_AUAS': '05mknbx32'}

# %%
def fetch_authors_by_ror(ror_id, n_max=400):
    all_authors_data = []
    processed_count = 0
    start_time = time.time()

    try:
        query = Authors().filter(affiliations={"institution": {"ror":ror_id}})
        
        for author in chain(*query.paginate(per_page=200, n_max=n_max)):
            processed_count += 1

            if processed_count % 200 == 0:
                elapsed_time = time.time() - start_time
                print(
                    f"Processed {processed_count} authors... (Time elapsed: {elapsed_time:.2f}s)")
                
            if processed_count == 1:
                print("Keys:", author.keys())
                print("AUTHOR:", author)
                        
            all_authors_data.append({
                "affiliations": author.get('affiliations', []),
                "cited_by_count": author.get('cited_by_count'),
                "last_known_insitution":author.get('last_known_institution', []),
                "orcid": author.get('orcid'),
                "scopus": author.get('scopus'),
                "summary_stats":author.get('summary_get',[]),
                "works_count":author.get('works_count'),
                "concepts":author.get('concepts',[]),
                'openalex_id':author.get('openalex')
            })
        
        end_time = time.time()
        print(f"\nFinished fetching.")
        print(f"Total authors found and processed: {len(all_authors_data)}")
        print(f"Total time taken: {end_time - start_time:.2f} seconds")
        
        return all_authors_data

    except Exception as e:
        print(f"\nAn error occurred during fetching: {e}")
        print(f"Processed {processed_count} authors before the error.")
        return []
            
# ROR for the specific university
ROR_ID = universities_ror_id['PL_ZUT']
print(f"Fetching authors for institution ROR: {ROR_ID}")
# # Fetch authors for the specified ROR ID
example_authors_data = fetch_authors_by_ror(ROR_ID)
# Out:
# Fetching authors for institution ROR: 0596m7f19
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5010715704', 'orcid': 'https://orcid.org/0000-0002-2241-9764', 'display_name': 'Оleg G. Sinyashin', 'display_name_alternatives': ['O. G. Sinyashin', "Oleg Gerol'dovich Sinyashin", 'Оleg G. Sinyashin', 'Oleg G. Sinyashin', 'Oleg. G. Sinyashin', 'O.G Sinyashin', 'O. Sinyashin', 'O. G. Sinyashina', 'Oleg Geroldovich Sinyashin', 'O. G. Sinyáshin', 'Oleg Sinyashin'], 'works_count': 1141, 'cited_by_count': 8358, 'summary_stats': {'2yr_mean_citedness': 1.783132530120482, 'h_index': 41, 'i10_index': 259}, 'ids': {'openalex': 'https://openalex.org/A5010715704', 'orcid': 'https://orcid.org/0000-0002-2241-9764'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I4210131217', 'ror': 'https://ror.org/03jty3219', 'display_name': 'A.E. Arbuzov Institute of Organic and Physical Chemistry', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I1313323035', 'https://openalex.org/I4210131217', 'https://openalex.org/I4210145551']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I4210093042', 'ror': 'https://ror.org/00g4bcb66', 'display_name': 'Kazan Scientific Center', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I1313323035', 'https://openalex.org/I4210093042', 'https://openalex.org/I4210160366']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I1313323035', 'ror': 'https://ror.org/05qrfxd25', 'display_name': 'Russian Academy of Sciences', 'country_code': 'RU', 'type': 'government', 'lineage': ['https://openalex.org/I1313323035']}, 'years': [2024, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013]}, {'institution': {'id': 'https://openalex.org/I21203515', 'ror': 'https://ror.org/05256ym39', 'display_name': 'Kazan Federal University', 'country_code': 'RU', 'type': 'funder', 'lineage': ['https://openalex.org/I21203515']}, 'years': [2024, 2001]}, {'institution': {'id': 'https://openalex.org/I4389424196', 'ror': None, 'display_name': 'Deleted Institution', 'country_code': None, 'type': None, 'lineage': ['https://openalex.org/I4389424196']}, 'years': [2024]}, {'institution': {'id': 'https://openalex.org/I4210106238', 'ror': 'https://ror.org/01jgbgc06', 'display_name': 'A.V. Topchiev Institute of Petrochemical Synthesis', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I1313323035', 'https://openalex.org/I4210106238', 'https://openalex.org/I4210145551', 'https://openalex.org/I4210163714']}, 'years': [2021]}, {'institution': {'id': 'https://openalex.org/I4210103676', 'ror': 'https://ror.org/018rhs370', 'display_name': 'IFC Research (United Kingdom)', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210103676']}, 'years': [2021]}, {'institution': {'id': 'https://openalex.org/I205237279', 'ror': 'https://ror.org/01y1kjr75', 'display_name': 'Nankai University', 'country_code': 'CN', 'type': 'funder', 'lineage': ['https://openalex.org/I205237279']}, 'years': [2020]}, {'institution': {'id': 'https://openalex.org/I54195498', 'ror': 'https://ror.org/03shav252', 'display_name': 'Kazan State Technological University', 'country_code': 'RU', 'type': 'education', 'lineage': ['https://openalex.org/I54195498']}, 'years': [2019, 2018, 2017, 2016, 2015, 2014, 2010, 2008, 2007, 2006]}, {'institution': {'id': 'https://openalex.org/I155313962', 'ror': 'https://ror.org/0596m7f19', 'display_name': 'West Pomeranian University of Technology', 'country_code': 'PL', 'type': 'funder', 'lineage': ['https://openalex.org/I155313962']}, 'years': [2019]}], 'last_known_institutions': [{'id': 'https://openalex.org/I4210131217', 'ror': 'https://ror.org/03jty3219', 'display_name': 'A.E. Arbuzov Institute of Organic and Physical Chemistry', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I1313323035', 'https://openalex.org/I4210131217', 'https://openalex.org/I42 ...
# Processed 200 authors... (Time elapsed: 3.87s)
# Processed 400 authors... (Time elapsed: 3.87s)
#
# Finished fetching.
# Total authors found and processed: 400
# Total time taken: 3.89 seconds

# %%
universities_authors = {}

for key in universities_ror_id:
    ror_id = universities_ror_id[key]
    print(f"Fetching authors for institution {key}")
    # n_max change to None to fetch all
    authors_data = fetch_authors_by_ror(ror_id, n_max=None)
    universities_authors[key] = authors_data

print(len(universities_authors))
# Out:
# Fetching authors for institution PL_ZUT
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5010715704', 'orcid': 'https://orcid.org/0000-0002-2241-9764', 'display_name': 'Оleg G. Sinyashin', 'display_name_alternatives': ['O. G. Sinyashin', "Oleg Gerol'dovich Sinyashin", 'Оleg G. Sinyashin', 'Oleg G. Sinyashin', 'Oleg. G. Sinyashin', 'O.G Sinyashin', 'O. Sinyashin', 'O. G. Sinyashina', 'Oleg Geroldovich Sinyashin', 'O. G. Sinyáshin', 'Oleg Sinyashin'], 'works_count': 1141, 'cited_by_count': 8358, 'summary_stats': {'2yr_mean_citedness': 1.783132530120482, 'h_index': 41, 'i10_index': 259}, 'ids': {'openalex': 'https://openalex.org/A5010715704', 'orcid': 'https://orcid.org/0000-0002-2241-9764'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I4210131217', 'ror': 'https://ror.org/03jty3219', 'display_name': 'A.E. Arbuzov Institute of Organic and Physical Chemistry', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I1313323035', 'https://openalex.org/I4210131217', 'https://openalex.org/I4210145551']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I4210093042', 'ror': 'https://ror.org/00g4bcb66', 'display_name': 'Kazan Scientific Center', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I1313323035', 'https://openalex.org/I4210093042', 'https://openalex.org/I4210160366']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I1313323035', 'ror': 'https://ror.org/05qrfxd25', 'display_name': 'Russian Academy of Sciences', 'country_code': 'RU', 'type': 'government', 'lineage': ['https://openalex.org/I1313323035']}, 'years': [2024, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013]}, {'institution': {'id': 'https://openalex.org/I21203515', 'ror': 'https://ror.org/05256ym39', 'display_name': 'Kazan Federal University', 'country_code': 'RU', 'type': 'funder', 'lineage': ['https://openalex.org/I21203515']}, 'years': [2024, 2001]}, {'institution': {'id': 'https://openalex.org/I4389424196', 'ror': None, 'display_name': 'Deleted Institution', 'country_code': None, 'type': None, 'lineage': ['https://openalex.org/I4389424196']}, 'years': [2024]}, {'institution': {'id': 'https://openalex.org/I4210106238', 'ror': 'https://ror.org/01jgbgc06', 'display_name': 'A.V. Topchiev Institute of Petrochemical Synthesis', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I1313323035', 'https://openalex.org/I4210106238', 'https://openalex.org/I4210145551', 'https://openalex.org/I4210163714']}, 'years': [2021]}, {'institution': {'id': 'https://openalex.org/I4210103676', 'ror': 'https://ror.org/018rhs370', 'display_name': 'IFC Research (United Kingdom)', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I4210103676']}, 'years': [2021]}, {'institution': {'id': 'https://openalex.org/I205237279', 'ror': 'https://ror.org/01y1kjr75', 'display_name': 'Nankai University', 'country_code': 'CN', 'type': 'funder', 'lineage': ['https://openalex.org/I205237279']}, 'years': [2020]}, {'institution': {'id': 'https://openalex.org/I54195498', 'ror': 'https://ror.org/03shav252', 'display_name': 'Kazan State Technological University', 'country_code': 'RU', 'type': 'education', 'lineage': ['https://openalex.org/I54195498']}, 'years': [2019, 2018, 2017, 2016, 2015, 2014, 2010, 2008, 2007, 2006]}, {'institution': {'id': 'https://openalex.org/I155313962', 'ror': 'https://ror.org/0596m7f19', 'display_name': 'West Pomeranian University of Technology', 'country_code': 'PL', 'type': 'funder', 'lineage': ['https://openalex.org/I155313962']}, 'years': [2019]}], 'last_known_institutions': [{'id': 'https://openalex.org/I4210131217', 'ror': 'https://ror.org/03jty3219', 'display_name': 'A.E. Arbuzov Institute of Organic and Physical Chemistry', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I1313323035', 'https://openalex.org/I4210131217', 'https://openalex.org/I42 ...
# Processed 200 authors... (Time elapsed: 32.26s)
# Processed 400 authors... (Time elapsed: 32.27s)
# Processed 600 authors... (Time elapsed: 32.27s)
# Processed 800 authors... (Time elapsed: 32.27s)
# Processed 1000 authors... (Time elapsed: 32.27s)
# Processed 1200 authors... (Time elapsed: 32.27s)
# Processed 1400 authors... (Time elapsed: 32.27s)
# Processed 1600 authors... (Time elapsed: 32.27s)
# Processed 1800 authors... (Time elapsed: 32.27s)
# Processed 2000 authors... (Time elapsed: 32.27s)
# Processed 2200 authors... (Time elapsed: 32.27s)
# Processed 2400 authors... (Time elapsed: 32.27s)
# Processed 2600 authors... (Time elapsed: 32.27s)
# Processed 2800 authors... (Time elapsed: 32.27s)
# Processed 3000 authors... (Time elapsed: 32.27s)
# Processed 3200 authors... (Time elapsed: 32.27s)
# Processed 3400 authors... (Time elapsed: 32.27s)
#
# Finished fetching.
# Total authors found and processed: 3518
# Total time taken: 32.36 seconds
# Fetching authors for institution BG_BFU
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5077723508', 'orcid': 'https://orcid.org/0000-0001-5174-9693', 'display_name': 'Diego Calvanese', 'display_name_alternatives': ['Diego Calvanese', 'Calvanese Diego', 'D. Calvanese'], 'works_count': 535, 'cited_by_count': 26452, 'summary_stats': {'2yr_mean_citedness': 5.875, 'h_index': 66, 'i10_index': 247}, 'ids': {'openalex': 'https://openalex.org/A5077723508', 'orcid': 'https://orcid.org/0000-0001-5174-9693', 'scopus': 'http://www.scopus.com/inward/authorDetails.url?authorID=7004220724&partnerID=MN8TOARS'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I171543936', 'ror': 'https://ror.org/012ajp527', 'display_name': 'Free University of Bozen-Bolzano', 'country_code': 'IT', 'type': 'funder', 'lineage': ['https://openalex.org/I171543936']}, 'years': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015]}, {'institution': {'id': 'https://openalex.org/I90267481', 'ror': 'https://ror.org/05kb8h459', 'display_name': 'Umeå University', 'country_code': 'SE', 'type': 'funder', 'lineage': ['https://openalex.org/I90267481']}, 'years': [2024, 2023, 2022, 2021, 2020]}, {'institution': {'id': 'https://openalex.org/I31072267', 'ror': 'https://ror.org/02ek1bx64', 'display_name': 'Burgas Free University', 'country_code': 'BG', 'type': 'education', 'lineage': ['https://openalex.org/I31072267']}, 'years': [2021, 2018]}, {'institution': {'id': 'https://openalex.org/I861853513', 'ror': 'https://ror.org/02be6w209', 'display_name': 'Sapienza University of Rome', 'country_code': 'IT', 'type': 'funder', 'lineage': ['https://openalex.org/I861853513']}, 'years': [2013, 2011, 2007, 2005, 2004, 2003, 2002, 2001, 2000, 1999]}, {'institution': {'id': 'https://openalex.org/I98259816', 'ror': 'https://ror.org/02mb95055', 'display_name': 'Birkbeck, University of London', 'country_code': 'GB', 'type': 'funder', 'lineage': ['https://openalex.org/I124357947', 'https://openalex.org/I98259816']}, 'years': [2009]}, {'institution': {'id': 'https://openalex.org/I4210135132', 'ror': 'https://ror.org/03jsdjx34', 'display_name': 'Cambridge University Press', 'country_code': 'GB', 'type': 'company', 'lineage': ['https://openalex.org/I241749', 'https://openalex.org/I4210135132']}, 'years': [2009]}, {'institution': {'id': 'https://openalex.org/I28407311', 'ror': 'https://ror.org/027m9bs27', 'display_name': 'University of Manchester', 'country_code': 'GB', 'type': 'funder', 'lineage': ['https://openalex.org/I28407311']}, 'years': [2008]}, {'institution': {'id': 'https://openalex.org/I188760350', 'ror': 'https://ror.org/03bea9k73', 'display_name': 'Ollscoil na Gaillimhe – University of Galway', 'country_code': 'IE', 'type': 'funder', 'lineage': ['https://openalex.org/I188760350']}, 'years': [2008]}, {'institution': {'id': 'https://openalex.org/I2802623135', 'ror': 'https://ror.org/023z51242', 'display_name': 'Enterprise Ireland', 'country_code': 'IE', 'type': 'government', 'lineage': ['https://openalex.org/I2802623135']}, 'years': [2008]}, {'institution': {'id': 'https://openalex.org/I190249584', 'ror': 'https://ror.org/054pv6659', 'display_name': 'Universität Innsbruck', 'country_code': 'AT', 'type': 'funder', 'lineage': ['https://openalex.org/I190249584']}, 'years': [2008]}], 'last_known_institutions': [{'id': 'https://openalex.org/I171543936', 'ror': 'https://ror.org/012ajp527', 'display_name': 'Free University of Bozen-Bolzano', 'country_code': 'IT', 'type': 'funder', 'lineage': ['https://openalex.org/I171543936']}, {'id': 'https://openalex.org/I90267481', 'ror': 'https://ror.org/05kb8h459', 'display_name': 'Umeå University', 'country_code': 'SE', 'type': 'funder', 'lineage': ['https://openalex.org/I90267481']}], 'topics': [{'id': 'https://openalex.org/T10215', 'display_name': 'Semantic Web and Ontologies', 'count': 405, 'subfield': {'id': 'https://openalex.org/subfields/1702', 'display_name': 'Artificial Intelligence'}, 'field': {'id': 'https://openalex.org/fields/17', 'display_name': 'Computer Science'}, 'dom ...
# Processed 200 authors... (Time elapsed: 2.46s)
# Processed 400 authors... (Time elapsed: 2.46s)
#
# Finished fetching.
# Total authors found and processed: 400
# Total time taken: 2.46 seconds
# Fetching authors for institution GR_UOP
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5073613780', 'orcid': 'https://orcid.org/0000-0001-6527-457X', 'display_name': 'Andrew K. Burroughs', 'display_name_alternatives': ['A. Burroughs', 'A. K Burroughs', 'Andrew Kenneth Burroughs', 'Andrew Burroughs', 'Andrew K. Burroughs', 'A. K. Burroughs'], 'works_count': 1666, 'cited_by_count': 54871, 'summary_stats': {'2yr_mean_citedness': 0.0, 'h_index': 114, 'i10_index': 502}, 'ids': {'openalex': 'https://openalex.org/A5073613780', 'orcid': 'https://orcid.org/0000-0001-6527-457X'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I2801138448', 'ror': 'https://ror.org/01ge67z96', 'display_name': 'The Royal Free Hospital', 'country_code': 'GB', 'type': 'healthcare', 'lineage': ['https://openalex.org/I169248724', 'https://openalex.org/I2801138448']}, 'years': [2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009]}, {'institution': {'id': 'https://openalex.org/I45129253', 'ror': 'https://ror.org/02jx3x895', 'display_name': 'University College London', 'country_code': 'GB', 'type': 'funder', 'lineage': ['https://openalex.org/I124357947', 'https://openalex.org/I45129253']}, 'years': [2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009]}, {'institution': {'id': 'https://openalex.org/I169248724', 'ror': 'https://ror.org/04rtdp853', 'display_name': 'Royal Free London NHS Foundation Trust', 'country_code': 'GB', 'type': 'healthcare', 'lineage': ['https://openalex.org/I169248724']}, 'years': [2018, 2017, 2015, 2014, 2013, 2012, 2011, 2008, 2007, 2006]}, {'institution': {'id': 'https://openalex.org/I2802789809', 'ror': 'https://ror.org/009bsy196', 'display_name': 'Edinburgh Royal Infirmary', 'country_code': 'GB', 'type': 'healthcare', 'lineage': ['https://openalex.org/I2802789809']}, 'years': [2018]}, {'institution': {'id': 'https://openalex.org/I89466785', 'ror': 'https://ror.org/02hcv4z63', 'display_name': 'Minia University', 'country_code': 'EG', 'type': 'funder', 'lineage': ['https://openalex.org/I89466785']}, 'years': [2016]}, {'institution': {'id': 'https://openalex.org/I2800173700', 'ror': 'https://ror.org/024atcf19', 'display_name': 'UCL Australia', 'country_code': 'AU', 'type': 'education', 'lineage': ['https://openalex.org/I2800173700']}, 'years': [2015, 2012, 2010, 2007, 2006, 2005]}, {'institution': {'id': 'https://openalex.org/I4210094195', 'ror': 'https://ror.org/00htrxv69', 'display_name': 'Azienda Socio Sanitaria Territoriale Grande Ospedale Metropolitano Niguarda', 'country_code': 'IT', 'type': 'healthcare', 'lineage': ['https://openalex.org/I4210094195']}, 'years': [2015]}, {'institution': {'id': 'https://openalex.org/I4210138654', 'ror': 'https://ror.org/0312m2266', 'display_name': 'University Hospital of Heraklion', 'country_code': 'GR', 'type': 'healthcare', 'lineage': ['https://openalex.org/I4210138654']}, 'years': [2014, 2000]}, {'institution': {'id': 'https://openalex.org/I174878644', 'ror': 'https://ror.org/017wvtq80', 'display_name': 'University of Patras', 'country_code': 'GR', 'type': 'funder', 'lineage': ['https://openalex.org/I174878644']}, 'years': [2014]}, {'institution': {'id': 'https://openalex.org/I4210098345', 'ror': 'https://ror.org/00xqj7528', 'display_name': 'British Nuclear Medicine Society', 'country_code': 'GB', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I4210098345']}, 'years': [2014]}], 'last_known_institutions': [{'id': 'https://openalex.org/I169248724', 'ror': 'https://ror.org/04rtdp853', 'display_name': 'Royal Free London NHS Foundation Trust', 'country_code': 'GB', 'type': 'healthcare', 'lineage': ['https://openalex.org/I169248724']}, {'id': 'https://openalex.org/I45129253', 'ror': 'https://ror.org/02jx3x895', 'display_name': 'University College London', 'country_code': 'GB', 'type': 'funder', 'lineage': ['https://openalex.org/I124357947', 'https://openalex.org/I45129253']}], 'topics': [{'id': 'https://openalex.org/T10337', 'display_name': 'Liver Disease and Transplantation', 'count': 459, 'subfield': {'id': 'http ...
# Processed 200 authors... (Time elapsed: 177.74s)
# Processed 400 authors... (Time elapsed: 177.74s)
# Processed 600 authors... (Time elapsed: 177.74s)
# Processed 800 authors... (Time elapsed: 177.74s)
# Processed 1000 authors... (Time elapsed: 177.74s)
# Processed 1200 authors... (Time elapsed: 177.74s)
# Processed 1400 authors... (Time elapsed: 177.75s)
# Processed 1600 authors... (Time elapsed: 177.75s)
# Processed 1800 authors... (Time elapsed: 177.75s)
# Processed 2000 authors... (Time elapsed: 177.75s)
# Processed 2200 authors... (Time elapsed: 177.76s)
# Processed 2400 authors... (Time elapsed: 177.76s)
# Processed 2600 authors... (Time elapsed: 177.76s)
# Processed 2800 authors... (Time elapsed: 177.76s)
# Processed 3000 authors... (Time elapsed: 177.76s)
# Processed 3200 authors... (Time elapsed: 177.76s)
# Processed 3400 authors... (Time elapsed: 177.76s)
# Processed 3600 authors... (Time elapsed: 177.76s)
# Processed 3800 authors... (Time elapsed: 177.76s)
# Processed 4000 authors... (Time elapsed: 177.76s)
# Processed 4200 authors... (Time elapsed: 177.76s)
# Processed 4400 authors... (Time elapsed: 177.76s)
# Processed 4600 authors... (Time elapsed: 177.76s)
# Processed 4800 authors... (Time elapsed: 177.76s)
# Processed 5000 authors... (Time elapsed: 177.76s)
# Processed 5200 authors... (Time elapsed: 177.76s)
# Processed 5400 authors... (Time elapsed: 177.76s)
# Processed 5600 authors... (Time elapsed: 177.77s)
# Processed 5800 authors... (Time elapsed: 177.77s)
# Processed 6000 authors... (Time elapsed: 177.77s)
# Processed 6200 authors... (Time elapsed: 177.77s)
# Processed 6400 authors... (Time elapsed: 177.77s)
# Processed 6600 authors... (Time elapsed: 177.77s)
# Processed 6800 authors... (Time elapsed: 177.77s)
# Processed 7000 authors... (Time elapsed: 177.77s)
# Processed 7200 authors... (Time elapsed: 177.77s)
# Processed 7400 authors... (Time elapsed: 177.77s)
# Processed 7600 authors... (Time elapsed: 177.77s)
# Processed 7800 authors... (Time elapsed: 177.77s)
# Processed 8000 authors... (Time elapsed: 177.77s)
# Processed 8200 authors... (Time elapsed: 177.77s)
# Processed 8400 authors... (Time elapsed: 177.77s)
# Processed 8600 authors... (Time elapsed: 177.77s)
# Processed 8800 authors... (Time elapsed: 177.77s)
# Processed 9000 authors... (Time elapsed: 177.77s)
# Processed 9200 authors... (Time elapsed: 177.77s)
# Processed 9400 authors... (Time elapsed: 177.77s)
# Processed 9600 authors... (Time elapsed: 177.77s)
# Processed 9800 authors... (Time elapsed: 177.77s)
# Processed 10000 authors... (Time elapsed: 177.77s)
# Processed 10200 authors... (Time elapsed: 177.77s)
# Processed 10400 authors... (Time elapsed: 177.77s)
# Processed 10600 authors... (Time elapsed: 177.78s)
# Processed 10800 authors... (Time elapsed: 177.78s)
# Processed 11000 authors... (Time elapsed: 177.78s)
# Processed 11200 authors... (Time elapsed: 177.78s)
# Processed 11400 authors... (Time elapsed: 177.78s)
# Processed 11600 authors... (Time elapsed: 177.79s)
# Processed 11800 authors... (Time elapsed: 177.79s)
# Processed 12000 authors... (Time elapsed: 177.79s)
# Processed 12200 authors... (Time elapsed: 177.79s)
# Processed 12400 authors... (Time elapsed: 177.79s)
# Processed 12600 authors... (Time elapsed: 177.79s)
# Processed 12800 authors... (Time elapsed: 177.79s)
# Processed 13000 authors... (Time elapsed: 177.79s)
# Processed 13200 authors... (Time elapsed: 177.79s)
# Processed 13400 authors... (Time elapsed: 177.79s)
# Processed 13600 authors... (Time elapsed: 177.79s)
# Processed 13800 authors... (Time elapsed: 177.79s)
# Processed 14000 authors... (Time elapsed: 177.79s)
# Processed 14200 authors... (Time elapsed: 177.79s)
# Processed 14400 authors... (Time elapsed: 177.79s)
# Processed 14600 authors... (Time elapsed: 177.79s)
# Processed 14800 authors... (Time elapsed: 177.79s)
# Processed 15000 authors... (Time elapsed: 177.79s)
# Processed 15200 authors... (Time elapsed: 177.80s)
# Processed 15400 authors... (Time elapsed: 177.80s)
# Processed 15600 authors... (Time elapsed: 177.80s)
# Processed 15800 authors... (Time elapsed: 177.80s)
# Processed 16000 authors... (Time elapsed: 177.80s)
# Processed 16200 authors... (Time elapsed: 177.80s)
# Processed 16400 authors... (Time elapsed: 177.80s)
# Processed 16600 authors... (Time elapsed: 177.80s)
# Processed 16800 authors... (Time elapsed: 177.80s)
# Processed 17000 authors... (Time elapsed: 177.80s)
#
# Finished fetching.
# Total authors found and processed: 17085
# Total time taken: 178.48 seconds
# Fetching authors for institution HR_UNIDU
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5061244096', 'orcid': 'https://orcid.org/0000-0002-9333-7221', 'display_name': 'Lovorka Čoralić', 'display_name_alternatives': ['L Coralic', 'Lovorka Čoralić', 'Lovorka Coralic', 'L. Čoralić'], 'works_count': 669, 'cited_by_count': 143, 'summary_stats': {'2yr_mean_citedness': 0.0, 'h_index': 4, 'i10_index': 3}, 'ids': {'openalex': 'https://openalex.org/A5061244096', 'orcid': 'https://orcid.org/0000-0002-9333-7221', 'scopus': 'http://www.scopus.com/inward/authorDetails.url?authorID=6506931790&partnerID=MN8TOARS'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I3018591564', 'ror': 'https://ror.org/016xdy456', 'display_name': 'Croatian Institute of History', 'country_code': 'HR', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I3018591564']}, 'years': [2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014]}, {'institution': {'id': 'https://openalex.org/I4210144085', 'ror': 'https://ror.org/03n51vw80', 'display_name': 'Croatian Science Foundation', 'country_code': 'HR', 'type': 'government', 'lineage': ['https://openalex.org/I4210144085']}, 'years': [2022]}, {'institution': {'id': 'https://openalex.org/I4210142152', 'ror': 'https://ror.org/04fa4r544', 'display_name': 'ORCID', 'country_code': 'US', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I4210142152']}, 'years': [2021]}, {'institution': {'id': 'https://openalex.org/I4210128237', 'ror': 'https://ror.org/033y2mr45', 'display_name': 'Archivio di Stato di Venezia', 'country_code': 'IT', 'type': 'archive', 'lineage': ['https://openalex.org/I4210128237']}, 'years': [2021]}, {'institution': {'id': 'https://openalex.org/I180629606', 'ror': 'https://ror.org/05yptqp13', 'display_name': 'University of Dubrovnik', 'country_code': 'HR', 'type': 'education', 'lineage': ['https://openalex.org/I180629606']}, 'years': [2021]}, {'institution': {'id': 'https://openalex.org/I1301669915', 'ror': 'https://ror.org/03d04qg82', 'display_name': 'Croatian Academy of Sciences and Arts', 'country_code': 'HR', 'type': 'government', 'lineage': ['https://openalex.org/I1301669915']}, 'years': [2011]}, {'institution': {'id': 'https://openalex.org/I4210094658', 'ror': 'https://ror.org/00p574j49', 'display_name': 'Institut za filozofiju', 'country_code': 'HR', 'type': 'facility', 'lineage': ['https://openalex.org/I4210094658']}, 'years': [1994]}, {'institution': {'id': 'https://openalex.org/I4210098658', 'ror': 'https://ror.org/00h4fkb86', 'display_name': 'Hrvatski zavod za javno zdravstvo', 'country_code': 'HR', 'type': 'other', 'lineage': ['https://openalex.org/I4210098658']}, 'years': [1992]}], 'last_known_institutions': [{'id': 'https://openalex.org/I3018591564', 'ror': 'https://ror.org/016xdy456', 'display_name': 'Croatian Institute of History', 'country_code': 'HR', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I3018591564']}], 'topics': [{'id': 'https://openalex.org/T14008', 'display_name': 'Balkan and Eastern European Studies', 'count': 500, 'subfield': {'id': 'https://openalex.org/subfields/2002', 'display_name': 'Economics and Econometrics'}, 'field': {'id': 'https://openalex.org/fields/20', 'display_name': 'Economics, Econometrics and Finance'}, 'domain': {'id': 'https://openalex.org/domains/2', 'display_name': 'Social Sciences'}}, {'id': 'https://openalex.org/T13854', 'display_name': 'Historical Geography and Cartography', 'count': 56, 'subfield': {'id': 'https://openalex.org/subfields/3305', 'display_name': 'Geography, Planning and Development'}, 'field': {'id': 'https://openalex.org/fields/33', 'display_name': 'Social Sciences'}, 'domain': {'id': 'https://openalex.org/domains/2', 'display_name': 'Social Sciences'}}, {'id': 'https://openalex.org/T14178', 'display_name': 'Environmental Science and Water Management', 'count': 49, 'subfield': {'id': 'https://openalex.org/subfields/2312', 'display_name': 'Water Science and Technology'}, 'field': {'id': 'https://openalex.org/fields/23', 'display_name': 'Environmental Sci ...
# Processed 200 authors... (Time elapsed: 8.26s)
# Processed 400 authors... (Time elapsed: 8.74s)
# Processed 600 authors... (Time elapsed: 8.74s)
# Processed 800 authors... (Time elapsed: 8.74s)
# Processed 1000 authors... (Time elapsed: 8.74s)
# Processed 1200 authors... (Time elapsed: 8.74s)
#
# Finished fetching.
# Total authors found and processed: 1208
# Total time taken: 8.80 seconds
# Fetching authors for institution SL_EMUNI
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5033867684', 'orcid': 'https://orcid.org/0000-0002-8128-9533', 'display_name': 'Angelo Camerlenghi', 'display_name_alternatives': ['Camerlenghi Angelo', 'A. A. Camerlenghi', 'Angelo Camerlenghi', 'Angelo Alessandro Camerlenghi', 'A. Camerlenghi'], 'works_count': 357, 'cited_by_count': 7787, 'summary_stats': {'2yr_mean_citedness': 1.0740740740740742, 'h_index': 49, 'i10_index': 112}, 'ids': {'openalex': 'https://openalex.org/A5033867684', 'orcid': 'https://orcid.org/0000-0002-8128-9533', 'scopus': 'http://www.scopus.com/inward/authorDetails.url?authorID=6701342483&partnerID=MN8TOARS'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I4210164369', 'ror': 'https://ror.org/04y4t7k95', 'display_name': 'National Institute of Oceanography and Applied Geophysics', 'country_code': 'IT', 'type': 'facility', 'lineage': ['https://openalex.org/I4210164369']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I4210135109', 'ror': 'https://ror.org/03761pf32', 'display_name': 'Euro Mediterranean University', 'country_code': 'SI', 'type': 'education', 'lineage': ['https://openalex.org/I4210135109']}, 'years': [2025]}, {'institution': {'id': 'https://openalex.org/I75093019', 'ror': 'https://ror.org/01gvkyp03', 'display_name': 'National Institute of Oceanography', 'country_code': 'IN', 'type': 'funder', 'lineage': ['https://openalex.org/I2799351866', 'https://openalex.org/I4210134808', 'https://openalex.org/I66760702', 'https://openalex.org/I75093019']}, 'years': [2022, 2020]}, {'institution': {'id': 'https://openalex.org/I71999127', 'ror': 'https://ror.org/021018s57', 'display_name': 'Universitat de Barcelona', 'country_code': 'ES', 'type': 'funder', 'lineage': ['https://openalex.org/I71999127']}, 'years': [2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005]}, {'institution': {'id': 'https://openalex.org/I11932220', 'ror': 'https://ror.org/0371hy230', 'display_name': 'Institució Catalana de Recerca i Estudis Avançats', 'country_code': 'ES', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I11932220']}, 'years': [2013, 2011, 2010, 2009, 2008, 2007]}, {'institution': {'id': 'https://openalex.org/I2801626668', 'ror': 'https://ror.org/01dt7qh15', 'display_name': 'AREA Science Park', 'country_code': 'IT', 'type': 'archive', 'lineage': ['https://openalex.org/I2801626668']}, 'years': [2013]}, {'institution': {'id': 'https://openalex.org/I188592606', 'ror': 'https://ror.org/05709zb94', 'display_name': 'Hamilton College', 'country_code': 'US', 'type': 'funder', 'lineage': ['https://openalex.org/I188592606']}, 'years': [2001]}, {'institution': {'id': 'https://openalex.org/I189158943', 'ror': 'https://ror.org/00wjc7c48', 'display_name': 'University of Milan', 'country_code': 'IT', 'type': 'funder', 'lineage': ['https://openalex.org/I189158943']}, 'years': [1992, 1991, 1990, 1987, 1985, 1984]}], 'last_known_institutions': [{'id': 'https://openalex.org/I4210164369', 'ror': 'https://ror.org/04y4t7k95', 'display_name': 'National Institute of Oceanography and Applied Geophysics', 'country_code': 'IT', 'type': 'facility', 'lineage': ['https://openalex.org/I4210164369']}, {'id': 'https://openalex.org/I4210135109', 'ror': 'https://ror.org/03761pf32', 'display_name': 'Euro Mediterranean University', 'country_code': 'SI', 'type': 'education', 'lineage': ['https://openalex.org/I4210135109']}], 'topics': [{'id': 'https://openalex.org/T10017', 'display_name': 'Geology and Paleoclimatology Research', 'count': 135, 'subfield': {'id': 'https://openalex.org/subfields/1902', 'display_name': 'Atmospheric Science'}, 'field': {'id': 'https://openalex.org/fields/19', 'display_name': 'Earth and Planetary Sciences'}, 'domain': {'id': 'https://openalex.org/domains/3', 'display_name': 'Physical Sciences'}}, {'id': 'https://openalex.org/T10995', 'display_name': 'Methane Hydrates and Related Phenomena', 'count': 123, 'subfield': {'id': 'https://openalex.org/ ...
#
# Finished fetching.
# Total authors found and processed: 53
# Total time taken: 1.15 seconds
# Fetching authors for institution IT_UNISS
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5043059300', 'orcid': 'https://orcid.org/0000-0003-0658-4919', 'display_name': 'G. Lafferty', 'display_name_alternatives': ['G. D Lafferty', 'G. D. Lafferty', 'G D. Lafferty', 'Grace Lafferty', 'George D. Lafferty', 'G. Lafferty', 'George Lafferty'], 'works_count': 2534, 'cited_by_count': 89431, 'summary_stats': {'2yr_mean_citedness': 4.239130434782608, 'h_index': 130, 'i10_index': 1473}, 'ids': {'openalex': 'https://openalex.org/A5043059300', 'orcid': 'https://orcid.org/0000-0003-0658-4919'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I28407311', 'ror': 'https://ror.org/027m9bs27', 'display_name': 'University of Manchester', 'country_code': 'GB', 'type': 'funder', 'lineage': ['https://openalex.org/I28407311']}, 'years': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015]}, {'institution': {'id': 'https://openalex.org/I204722609', 'ror': 'https://ror.org/02y72wh86', 'display_name': "Queen's University", 'country_code': 'CA', 'type': 'funder', 'lineage': ['https://openalex.org/I204722609']}, 'years': [2024]}, {'institution': {'id': 'https://openalex.org/I40120149', 'ror': 'https://ror.org/052gg0110', 'display_name': 'University of Oxford', 'country_code': 'GB', 'type': 'funder', 'lineage': ['https://openalex.org/I40120149']}, 'years': [2023]}, {'institution': {'id': 'https://openalex.org/I4210130434', 'ror': 'https://ror.org/037styt87', 'display_name': 'Petersburg Nuclear Physics Institute', 'country_code': 'RU', 'type': 'funder', 'lineage': ['https://openalex.org/I1313323035', 'https://openalex.org/I4210096333', 'https://openalex.org/I4210130434']}, 'years': [2021, 2016, 2014, 2013, 2012]}, {'institution': {'id': 'https://openalex.org/I4843557', 'ror': 'https://ror.org/03e5eem51', 'display_name': 'Budker Institute of Nuclear Physics', 'country_code': 'RU', 'type': 'facility', 'lineage': ['https://openalex.org/I1313323035', 'https://openalex.org/I4210096333', 'https://openalex.org/I4210127387', 'https://openalex.org/I4843557']}, 'years': [2020, 2014]}, {'institution': {'id': 'https://openalex.org/I4210137180', 'ror': 'https://ror.org/03v8tnc06', 'display_name': 'Institute of High Energy Physics', 'country_code': 'CN', 'type': 'funder', 'lineage': ['https://openalex.org/I19820366', 'https://openalex.org/I4210137180']}, 'years': [2020]}, {'institution': {'id': 'https://openalex.org/I4210165038', 'ror': 'https://ror.org/05qbk4x57', 'display_name': 'University of Chinese Academy of Sciences', 'country_code': 'CN', 'type': 'funder', 'lineage': ['https://openalex.org/I19820366', 'https://openalex.org/I4210165038']}, 'years': [2020]}, {'institution': {'id': 'https://openalex.org/I4210148700', 'ror': 'https://ror.org/04j0x0h93', 'display_name': 'Istituto Nazionale di Fisica Nucleare, Sezione di Bologna', 'country_code': 'IT', 'type': 'facility', 'lineage': ['https://openalex.org/I160013858', 'https://openalex.org/I4210148700']}, 'years': [2020, 1999, 1992]}, {'institution': {'id': 'https://openalex.org/I9360294', 'ror': 'https://ror.org/01111rn36', 'display_name': 'University of Bologna', 'country_code': 'IT', 'type': 'funder', 'lineage': ['https://openalex.org/I9360294']}, 'years': [2020, 1999, 1992]}, {'institution': {'id': 'https://openalex.org/I159650629', 'ror': 'https://ror.org/01bnjbv91', 'display_name': 'University of Sassari', 'country_code': 'IT', 'type': 'funder', 'lineage': ['https://openalex.org/I159650629']}, 'years': [2020]}], 'last_known_institutions': [{'id': 'https://openalex.org/I204722609', 'ror': 'https://ror.org/02y72wh86', 'display_name': "Queen's University", 'country_code': 'CA', 'type': 'funder', 'lineage': ['https://openalex.org/I204722609']}, {'id': 'https://openalex.org/I28407311', 'ror': 'https://ror.org/027m9bs27', 'display_name': 'University of Manchester', 'country_code': 'GB', 'type': 'funder', 'lineage': ['https://openalex.org/I28407311']}], 'topics': [{'id': 'https://openalex.org/T10048', 'display_name': 'Particle physics theoretical a ...
# Processed 200 authors... (Time elapsed: 85.98s)
# Processed 400 authors... (Time elapsed: 86.03s)
# Processed 600 authors... (Time elapsed: 86.03s)
# Processed 800 authors... (Time elapsed: 86.03s)
# Processed 1000 authors... (Time elapsed: 86.03s)
# Processed 1200 authors... (Time elapsed: 86.03s)
# Processed 1400 authors... (Time elapsed: 86.03s)
# Processed 1600 authors... (Time elapsed: 86.03s)
# Processed 1800 authors... (Time elapsed: 86.03s)
# Processed 2000 authors... (Time elapsed: 86.03s)
# Processed 2200 authors... (Time elapsed: 86.03s)
# Processed 2400 authors... (Time elapsed: 86.03s)
# Processed 2600 authors... (Time elapsed: 86.03s)
# Processed 2800 authors... (Time elapsed: 86.03s)
# Processed 3000 authors... (Time elapsed: 86.03s)
# Processed 3200 authors... (Time elapsed: 86.03s)
# Processed 3400 authors... (Time elapsed: 86.03s)
# Processed 3600 authors... (Time elapsed: 86.04s)
# Processed 3800 authors... (Time elapsed: 86.04s)
# Processed 4000 authors... (Time elapsed: 86.04s)
# Processed 4200 authors... (Time elapsed: 86.05s)
# Processed 4400 authors... (Time elapsed: 86.05s)
# Processed 4600 authors... (Time elapsed: 86.05s)
# Processed 4800 authors... (Time elapsed: 86.05s)
# Processed 5000 authors... (Time elapsed: 86.05s)
# Processed 5200 authors... (Time elapsed: 86.05s)
# Processed 5400 authors... (Time elapsed: 86.05s)
# Processed 5600 authors... (Time elapsed: 86.05s)
# Processed 5800 authors... (Time elapsed: 86.05s)
# Processed 6000 authors... (Time elapsed: 86.05s)
# Processed 6200 authors... (Time elapsed: 86.05s)
# Processed 6400 authors... (Time elapsed: 86.05s)
# Processed 6600 authors... (Time elapsed: 86.06s)
# Processed 6800 authors... (Time elapsed: 86.06s)
# Processed 7000 authors... (Time elapsed: 86.06s)
# Processed 7200 authors... (Time elapsed: 86.06s)
# Processed 7400 authors... (Time elapsed: 86.06s)
# Processed 7600 authors... (Time elapsed: 86.06s)
# Processed 7800 authors... (Time elapsed: 86.06s)
# Processed 8000 authors... (Time elapsed: 86.06s)
#
# Finished fetching.
# Total authors found and processed: 8167
# Total time taken: 86.48 seconds
# Fetching authors for institution FR_UAG
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5044745974', 'orcid': 'https://orcid.org/0000-0003-3067-077X', 'display_name': 'Michael S. Engel', 'display_name_alternatives': ['M. H. Engel', 'Monica Engel', 'M. S. Engel', 'MICHAEL S. ENGEL FLS', 'Michael S. Engel', 'M. Engel', 'Michael Engel', 'Mathieu Boderau', 'M. S Engel', 'Engel'], 'works_count': 1147, 'cited_by_count': 21595, 'summary_stats': {'2yr_mean_citedness': 2.6115702479338845, 'h_index': 63, 'i10_index': 458}, 'ids': {'openalex': 'https://openalex.org/A5044745974', 'orcid': 'https://orcid.org/0000-0003-3067-077X'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I1338124936', 'ror': 'https://ror.org/03thb3e06', 'display_name': 'American Museum of Natural History', 'country_code': 'US', 'type': 'funder', 'lineage': ['https://openalex.org/I1338124936']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I192513696', 'ror': 'https://ror.org/006vs7897', 'display_name': 'National University of San Marcos', 'country_code': 'PE', 'type': 'funder', 'lineage': ['https://openalex.org/I192513696']}, 'years': [2025, 2024]}, {'institution': {'id': 'https://openalex.org/I4210103322', 'ror': 'https://ror.org/01dadvw90', 'display_name': 'Institut de Systématique, Évolution, Biodiversité', 'country_code': 'FR', 'type': 'facility', 'lineage': ['https://openalex.org/I1294671590', 'https://openalex.org/I159885104', 'https://openalex.org/I2746051580', 'https://openalex.org/I39804081', 'https://openalex.org/I4210103322', 'https://openalex.org/I4210107625', 'https://openalex.org/I4210123595', 'https://openalex.org/I52585520']}, 'years': [2025, 2024, 2023]}, {'institution': {'id': 'https://openalex.org/I159885104', 'ror': 'https://ror.org/046b3cj80', 'display_name': 'École Pratique des Hautes Études', 'country_code': 'FR', 'type': 'education', 'lineage': ['https://openalex.org/I159885104', 'https://openalex.org/I2746051580']}, 'years': [2025, 2024, 2023]}, {'institution': {'id': 'https://openalex.org/I39804081', 'ror': 'https://ror.org/02en5vm52', 'display_name': 'Sorbonne Université', 'country_code': 'FR', 'type': 'funder', 'lineage': ['https://openalex.org/I39804081']}, 'years': [2025, 2024, 2023]}, {'institution': {'id': 'https://openalex.org/I1294671590', 'ror': 'https://ror.org/02feahw73', 'display_name': 'Centre National de la Recherche Scientifique', 'country_code': 'FR', 'type': 'government', 'lineage': ['https://openalex.org/I1294671590']}, 'years': [2025, 2024, 2023]}, {'institution': {'id': 'https://openalex.org/I52585520', 'ror': 'https://ror.org/02ryfmr77', 'display_name': 'Université des Antilles', 'country_code': 'GP', 'type': 'education', 'lineage': ['https://openalex.org/I52585520']}, 'years': [2025, 2024]}, {'institution': {'id': 'https://openalex.org/I35440088', 'ror': 'https://ror.org/05a28rw58', 'display_name': 'ETH Zurich', 'country_code': 'CH', 'type': 'funder', 'lineage': ['https://openalex.org/I2799323385', 'https://openalex.org/I35440088']}, 'years': [2025]}, {'institution': {'id': 'https://openalex.org/I146416000', 'ror': 'https://ror.org/001tmjg57', 'display_name': 'University of Kansas', 'country_code': 'US', 'type': 'funder', 'lineage': ['https://openalex.org/I146416000']}, 'years': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015]}, {'institution': {'id': 'https://openalex.org/I4210131020', 'ror': 'https://ror.org/02yse6y23', 'display_name': 'Central Park Conservancy', 'country_code': 'US', 'type': 'nonprofit', 'lineage': ['https://openalex.org/I4210131020']}, 'years': [2024, 2008]}], 'last_known_institutions': [{'id': 'https://openalex.org/I1338124936', 'ror': 'https://ror.org/03thb3e06', 'display_name': 'American Museum of Natural History', 'country_code': 'US', 'type': 'funder', 'lineage': ['https://openalex.org/I1338124936']}], 'topics': [{'id': 'https://openalex.org/T10487', 'display_name': 'Plant and animal studies', 'count': 756, 'subfield': {'id': 'https://openalex.or ...
# Processed 200 authors... (Time elapsed: 17.81s)
# Processed 400 authors... (Time elapsed: 17.81s)
# Processed 600 authors... (Time elapsed: 17.81s)
# Processed 800 authors... (Time elapsed: 17.81s)
# Processed 1000 authors... (Time elapsed: 17.88s)
# Processed 1200 authors... (Time elapsed: 17.88s)
# Processed 1400 authors... (Time elapsed: 17.88s)
# Processed 1600 authors... (Time elapsed: 17.88s)
# Processed 1800 authors... (Time elapsed: 17.88s)
# Processed 2000 authors... (Time elapsed: 17.88s)
#
# Finished fetching.
# Total authors found and processed: 2160
# Total time taken: 18.01 seconds
# Fetching authors for institution PT_UAC
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5061969675', 'orcid': 'https://orcid.org/0000-0001-7246-6182', 'display_name': 'Maria do Céu Patrão Neves', 'display_name_alternatives': ['Maria do Céu Patrao Neves', 'Maria Patrão Neves', 'Maria do Céu Patrão Neves', 'M. Neves', 'María do Céu Patrao Neves', 'Maria Neves', 'M. Patrão Neves', 'MarIa do Céu Patrão Neves', 'Maria do Céu Paträo Neves', 'M. Patrão Neves'], 'works_count': 598, 'cited_by_count': 443, 'summary_stats': {'2yr_mean_citedness': 0.8888888888888888, 'h_index': 12, 'i10_index': 13}, 'ids': {'openalex': 'https://openalex.org/A5061969675', 'orcid': 'https://orcid.org/0000-0001-7246-6182'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I115891769', 'ror': 'https://ror.org/04276xd64', 'display_name': 'Universidade dos Açores', 'country_code': 'PT', 'type': 'funder', 'lineage': ['https://openalex.org/I115891769']}, 'years': [2025, 2023, 2022, 2021, 2020, 2018, 2017, 2006, 2004]}, {'institution': {'id': 'https://openalex.org/I25169866', 'ror': 'https://ror.org/03b9snr86', 'display_name': 'Universidade Católica Portuguesa', 'country_code': 'PT', 'type': 'education', 'lineage': ['https://openalex.org/I25169866']}, 'years': [2023, 2017, 2016, 2015, 2014]}, {'institution': {'id': 'https://openalex.org/I4387930285', 'ror': 'https://ror.org/01ykr4004', 'display_name': 'Escola Superior de Saúde Atlântica', 'country_code': None, 'type': 'education', 'lineage': ['https://openalex.org/I4387930285']}, 'years': [2023]}, {'institution': {'id': 'https://openalex.org/I4210091481', 'ror': 'https://ror.org/00jrpyg10', 'display_name': 'Atlântica Instituto Universitário', 'country_code': 'PT', 'type': 'education', 'lineage': ['https://openalex.org/I4210091481']}, 'years': [2023]}, {'institution': {'id': 'https://openalex.org/I4403386780', 'ror': 'https://ror.org/03jz4tp02', 'display_name': 'Ordem dos Farmaceuticos', 'country_code': None, 'type': 'other', 'lineage': ['https://openalex.org/I4403386780']}, 'years': [2019]}, {'institution': {'id': 'https://openalex.org/I4210160579', 'ror': 'https://ror.org/05n5mpz07', 'display_name': 'Ordem dos Médicos', 'country_code': 'PT', 'type': 'government', 'lineage': ['https://openalex.org/I4210160579']}, 'years': [2019]}, {'institution': {'id': 'https://openalex.org/I4210099144', 'ror': 'https://ror.org/010bsbc18', 'display_name': 'Hospital Prof. Dr. Fernando Fonseca', 'country_code': 'PT', 'type': 'healthcare', 'lineage': ['https://openalex.org/I4210099144']}, 'years': [2013]}, {'institution': {'id': 'https://openalex.org/I211891151', 'ror': 'https://ror.org/042r36z33', 'display_name': 'Universidade do Estado do Pará', 'country_code': 'BR', 'type': 'education', 'lineage': ['https://openalex.org/I211891151']}, 'years': [2012]}], 'last_known_institutions': [{'id': 'https://openalex.org/I115891769', 'ror': 'https://ror.org/04276xd64', 'display_name': 'Universidade dos Açores', 'country_code': 'PT', 'type': 'funder', 'lineage': ['https://openalex.org/I115891769']}], 'topics': [{'id': 'https://openalex.org/T11537', 'display_name': 'Ethics in medical practice', 'count': 104, 'subfield': {'id': 'https://openalex.org/subfields/3600', 'display_name': 'General Health Professions'}, 'field': {'id': 'https://openalex.org/fields/36', 'display_name': 'Health Professions'}, 'domain': {'id': 'https://openalex.org/domains/4', 'display_name': 'Health Sciences'}}, {'id': 'https://openalex.org/T13417', 'display_name': 'Biomedical Ethics and Regulation', 'count': 33, 'subfield': {'id': 'https://openalex.org/subfields/2737', 'display_name': 'Physiology'}, 'field': {'id': 'https://openalex.org/fields/27', 'display_name': 'Medicine'}, 'domain': {'id': 'https://openalex.org/domains/4', 'display_name': 'Health Sciences'}}, {'id': 'https://openalex.org/T10582', 'display_name': 'Ethics in Clinical Research', 'count': 26, 'subfield': {'id': 'https://openalex.org/subfields/2739', 'display_name': 'Public Health, Environmental and Occupational Health'}, 'field': {'id': 'h ...
# Processed 200 authors... (Time elapsed: 20.48s)
# Processed 400 authors... (Time elapsed: 20.48s)
# Processed 600 authors... (Time elapsed: 20.48s)
# Processed 800 authors... (Time elapsed: 20.48s)
# Processed 1000 authors... (Time elapsed: 20.48s)
# Processed 1200 authors... (Time elapsed: 20.48s)
# Processed 1400 authors... (Time elapsed: 20.51s)
# Processed 1600 authors... (Time elapsed: 21.06s)
# Processed 1800 authors... (Time elapsed: 21.06s)
#
# Finished fetching.
# Total authors found and processed: 1986
# Total time taken: 21.14 seconds
# Fetching authors for institution ES_UIB
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# ...
# Processed 200 authors... (Time elapsed: 22.47s)
# Processed 400 authors... (Time elapsed: 22.47s)
# Processed 600 authors... (Time elapsed: 22.55s)
# Processed 800 authors... (Time elapsed: 22.55s)
# Processed 1000 authors... (Time elapsed: 22.55s)
# Processed 1200 authors... (Time elapsed: 22.56s)
# Processed 1400 authors... (Time elapsed: 22.56s)
# Processed 1600 authors... (Time elapsed: 22.56s)
# Processed 1800 authors... (Time elapsed: 22.56s)
# Processed 2000 authors... (Time elapsed: 22.56s)
# Processed 2200 authors... (Time elapsed: 22.56s)
# Processed 2400 authors... (Time elapsed: 22.56s)
#
# Finished fetching.
# Total authors found and processed: 2456
# Total time taken: 22.71 seconds
# Fetching authors for institution FO_UF
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5087050293', 'orcid': 'https://orcid.org/0000-0002-0712-2540', 'display_name': 'Gregor B. E. Jemec', 'display_name_alternatives': ['Gregor Borut Ernst Jemec', 'Gregor Borut Jemec', 'Gregor Be Jemec', 'Gregor B.E Jemec', 'GregorBE Jemec', 'G. Jemec', 'Gbe Jemec', 'Gregor B. E. Jemec', 'G. B Jemec', 'G.B.E Jemec', 'Gregor E. Jemec', 'Gregor E B Jemec', 'G. B. E. Jemec', 'G. B. Jemec', 'Jemec', 'Gregor BE. Jemec', 'GBE. Jemec', 'G. Borut Jemec', 'Gregor Jemec', 'Gregor B. Jemec', 'T Jemec', 'Hans Christian Wulf Gregor B.E. Jemec'], 'works_count': 956, 'cited_by_count': 36802, 'summary_stats': {'2yr_mean_citedness': 6.76, 'h_index': 95, 'i10_index': 491}, 'ids': {'openalex': 'https://openalex.org/A5087050293', 'orcid': 'https://orcid.org/0000-0002-0712-2540'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I124055696', 'ror': 'https://ror.org/035b05819', 'display_name': 'University of Copenhagen', 'country_code': 'DK', 'type': 'funder', 'lineage': ['https://openalex.org/I124055696']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I2799546111', 'ror': 'https://ror.org/00t2n7611', 'display_name': 'Roskilde Sygehus', 'country_code': 'DK', 'type': 'healthcare', 'lineage': ['https://openalex.org/I2799546111']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I4210087803', 'ror': 'https://ror.org/00363z010', 'display_name': 'Zealand University Hospital', 'country_code': 'DK', 'type': 'healthcare', 'lineage': ['https://openalex.org/I2799668677', 'https://openalex.org/I2802567020', 'https://openalex.org/I4210087803']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I2802582725', 'ror': 'https://ror.org/051dzw862', 'display_name': 'Gentofte Hospital', 'country_code': 'DK', 'type': 'healthcare', 'lineage': ['https://openalex.org/I2802582725']}, 'years': [2025, 1994, 1991, 1990]}, {'institution': {'id': 'https://openalex.org/I2802567020', 'ror': 'https://ror.org/05bpbnx46', 'display_name': 'Copenhagen University Hospital', 'country_code': 'DK', 'type': 'healthcare', 'lineage': ['https://openalex.org/I2802567020']}, 'years': [2025, 2009]}, {'institution': {'id': 'https://openalex.org/I153976015', 'ror': 'https://ror.org/05njb9z20', 'display_name': 'University of Ljubljana', 'country_code': 'SI', 'type': 'funder', 'lineage': ['https://openalex.org/I153976015']}, 'years': [2025]}, {'institution': {'id': 'https://openalex.org/I107707843', 'ror': 'https://ror.org/014axpa37', 'display_name': 'Roskilde University', 'country_code': 'DK', 'type': 'education', 'lineage': ['https://openalex.org/I107707843']}, 'years': [2024, 2019, 2012, 2008, 2006, 2002]}, {'institution': {'id': 'https://openalex.org/I103146751', 'ror': 'https://ror.org/05mwmd090', 'display_name': 'University of the Faroe Islands', 'country_code': 'FO', 'type': 'education', 'lineage': ['https://openalex.org/I103146751']}, 'years': [2024, 2019]}, {'institution': {'id': 'https://openalex.org/I56085075', 'ror': 'https://ror.org/03z77qz90', 'display_name': 'University of Tartu', 'country_code': 'EE', 'type': 'funder', 'lineage': ['https://openalex.org/I56085075']}, 'years': [2024]}, {'institution': {'id': 'https://openalex.org/I23923803', 'ror': 'https://ror.org/03yghzc09', 'display_name': 'University of Exeter', 'country_code': 'GB', 'type': 'funder', 'lineage': ['https://openalex.org/I23923803']}, 'years': [2024]}], 'last_known_institutions': [{'id': 'https://openalex.org/I2802582725', 'ror': 'https://ror.org/051dzw862', 'display_name': 'Gentofte Hospital', 'country_code': 'DK', 'type': 'healthcare', 'lineage': ['https://openalex.org/I2802582725']}], 'topics': [{'id': 'https://openalex.org/T12731', 'display_name': 'Hidradenitis Suppurativa and Treatments', 'count': 350, 'subfield': {'id': 'https://openalex.org/subfields/2708', 'd ...
# Processed 200 authors... (Time elapsed: 4.05s)
# Processed 400 authors... (Time elapsed: 4.05s)
# Processed 600 authors... (Time elapsed: 4.05s)
#
# Finished fetching.
# Total authors found and processed: 632
# Total time taken: 4.09 seconds
# Fetching authors for institution DE_HOCHSTRALSUND
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5037775556', 'orcid': 'https://orcid.org/0000-0002-8942-3776', 'display_name': 'David Maintz', 'display_name_alternatives': ['David C. Maintz', 'David Maintz', 'D. Maintz'], 'works_count': 614, 'cited_by_count': 12696, 'summary_stats': {'2yr_mean_citedness': 2.933333333333333, 'h_index': 60, 'i10_index': 234}, 'ids': {'openalex': 'https://openalex.org/A5037775556', 'orcid': 'https://orcid.org/0000-0002-8942-3776'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I4210153755', 'ror': 'https://ror.org/05mxhda18', 'display_name': 'University Hospital Cologne', 'country_code': 'DE', 'type': 'healthcare', 'lineage': ['https://openalex.org/I4210153755']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I136199984', 'ror': 'https://ror.org/03vek6s52', 'display_name': 'Harvard University', 'country_code': 'US', 'type': 'funder', 'lineage': ['https://openalex.org/I136199984']}, 'years': [2025, 2013, 2007, 2005, 2004]}, {'institution': {'id': 'https://openalex.org/I180923762', 'ror': 'https://ror.org/00rcxh774', 'display_name': 'University of Cologne', 'country_code': 'DE', 'type': 'funder', 'lineage': ['https://openalex.org/I180923762']}, 'years': [2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]}, {'institution': {'id': 'https://openalex.org/I4210148663', 'ror': 'https://ror.org/04g99jx54', 'display_name': 'University of Applied Sciences Stralsund', 'country_code': 'DE', 'type': 'education', 'lineage': ['https://openalex.org/I4210148663']}, 'years': [2025]}, {'institution': {'id': 'https://openalex.org/I48633490', 'ror': 'https://ror.org/04py2rh25', 'display_name': 'Mass General Brigham', 'country_code': 'US', 'type': 'healthcare', 'lineage': ['https://openalex.org/I48633490']}, 'years': [2025]}, {'institution': {'id': 'https://openalex.org/I4210149099', 'ror': 'https://ror.org/04f2wf871', 'display_name': 'Centrum für Integrierte Onkologie', 'country_code': 'DE', 'type': 'facility', 'lineage': ['https://openalex.org/I2799391451', 'https://openalex.org/I4210149099', 'https://openalex.org/I4210153755']}, 'years': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2015]}, {'institution': {'id': 'https://openalex.org/I2799391451', 'ror': 'https://ror.org/01xnwqx93', 'display_name': 'University Hospital Bonn', 'country_code': 'DE', 'type': 'healthcare', 'lineage': ['https://openalex.org/I2799391451']}, 'years': [2024, 2004]}, {'institution': {'id': 'https://openalex.org/I44260953', 'ror': 'https://ror.org/024z2rq82', 'display_name': 'Heinrich Heine University Düsseldorf', 'country_code': 'DE', 'type': 'funder', 'lineage': ['https://openalex.org/I44260953']}, 'years': [2024, 2016]}, {'institution': {'id': 'https://openalex.org/I4210089242', 'ror': 'https://ror.org/006k2kk72', 'display_name': 'Düsseldorf University Hospital', 'country_code': 'DE', 'type': 'healthcare', 'lineage': ['https://openalex.org/I4210089242']}, 'years': [2024, 2016]}, {'institution': {'id': 'https://openalex.org/I4210094797', 'ror': 'https://ror.org/00w8byr45', 'display_name': 'Integrated Oncology (United States)', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I4210094797']}, 'years': [2024, 2017]}], 'last_known_institutions': [{'id': 'https://openalex.org/I4210153755', 'ror': 'https://ror.org/05mxhda18', 'display_name': 'University Hospital Cologne', 'country_code': 'DE', 'type': 'healthcare', 'lineage': ['https://openalex.org/I4210153755']}, {'id': 'https://openalex.org/I180923762', 'ror': 'https://ror.org/00rcxh774', 'display_name': 'University of Cologne', 'country_code': 'DE', 'type': 'funder', 'lineage': ['https://openalex.org/I180923762']}], 'topics': [{'id': 'https://openalex.org/T12386', 'display_name': 'Advanced X-ray and CT Imaging', 'count': 185, 'subfield': {'id': 'https://openalex.org/subfields/2204', 'display_name': 'Biomedical Engineering'}, 'field': {'id': 'https://openalex.org/fields/22', 'disp ...
# Processed 200 authors... (Time elapsed: 3.41s)
# Processed 400 authors... (Time elapsed: 3.41s)
#
# Finished fetching.
# Total authors found and processed: 505
# Total time taken: 3.44 seconds
# Fetching authors for institution FI_AUAS
# Keys: dict_keys(['id', 'orcid', 'display_name', 'display_name_alternatives', 'works_count', 'cited_by_count', 'summary_stats', 'ids', 'affiliations', 'last_known_institutions', 'topics', 'topic_share', 'x_concepts', 'counts_by_year', 'works_api_url', 'updated_date', 'created_date'])
# AUTHOR: {'id': 'https://openalex.org/A5004991163', 'orcid': 'https://orcid.org/0000-0001-7994-1767', 'display_name': 'Godfrey Baldacchino', 'display_name_alternatives': ['G. Baldacchino', 'Godfrey Baldacchino'], 'works_count': 415, 'cited_by_count': 4882, 'summary_stats': {'2yr_mean_citedness': 0.5, 'h_index': 38, 'i10_index': 100}, 'ids': {'openalex': 'https://openalex.org/A5004991163', 'orcid': 'https://orcid.org/0000-0001-7994-1767', 'scopus': 'http://www.scopus.com/inward/authorDetails.url?authorID=55943518500&partnerID=MN8TOARS'}, 'affiliations': [{'institution': {'id': 'https://openalex.org/I197854408', 'ror': 'https://ror.org/03a62bv60', 'display_name': 'University of Malta', 'country_code': 'MT', 'type': 'funder', 'lineage': ['https://openalex.org/I197854408']}, 'years': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015]}, {'institution': {'id': 'https://openalex.org/I889458895', 'ror': 'https://ror.org/02zhqgq86', 'display_name': 'University of Hong Kong', 'country_code': 'HK', 'type': 'funder', 'lineage': ['https://openalex.org/I889458895']}, 'years': [2024]}, {'institution': {'id': 'https://openalex.org/I2801220772', 'ror': 'https://ror.org/05a01hn31', 'display_name': 'Mater Dei Hospital', 'country_code': 'MT', 'type': 'healthcare', 'lineage': ['https://openalex.org/I2801220772']}, 'years': [2022]}, {'institution': {'id': 'https://openalex.org/I22188714', 'ror': 'https://ror.org/02xh9x144', 'display_name': 'University of Prince Edward Island', 'country_code': 'CA', 'type': 'funder', 'lineage': ['https://openalex.org/I22188714']}, 'years': [2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010]}, {'institution': {'id': 'https://openalex.org/I138816502', 'ror': 'https://ror.org/050ra0n32', 'display_name': 'Université de Corse Pascal Paoli', 'country_code': 'FR', 'type': 'funder', 'lineage': ['https://openalex.org/I138816502']}, 'years': [2015, 2014, 2013]}, {'institution': {'id': 'https://openalex.org/I53276908', 'ror': 'https://ror.org/0008kv292', 'display_name': 'Marymount University', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I53276908']}, 'years': [2014]}, {'institution': {'id': 'https://openalex.org/I115891769', 'ror': 'https://ror.org/04276xd64', 'display_name': 'Universidade dos Açores', 'country_code': 'PT', 'type': 'funder', 'lineage': ['https://openalex.org/I115891769']}, 'years': [2013]}, {'institution': {'id': 'https://openalex.org/I129801699', 'ror': 'https://ror.org/01nfmeh72', 'display_name': 'University of Tasmania', 'country_code': 'AU', 'type': 'funder', 'lineage': ['https://openalex.org/I129801699']}, 'years': [2011]}, {'institution': {'id': 'https://openalex.org/I31746571', 'ror': 'https://ror.org/03r8z3t63', 'display_name': 'UNSW Sydney', 'country_code': 'AU', 'type': 'funder', 'lineage': ['https://openalex.org/I31746571']}, 'years': [2011]}, {'institution': {'id': 'https://openalex.org/I290569820', 'ror': 'https://ror.org/05mknbx32', 'display_name': 'Åland University of Applied Sciences', 'country_code': 'AX', 'type': 'education', 'lineage': ['https://openalex.org/I290569820']}, 'years': [2010]}], 'last_known_institutions': [{'id': 'https://openalex.org/I197854408', 'ror': 'https://ror.org/03a62bv60', 'display_name': 'University of Malta', 'country_code': 'MT', 'type': 'funder', 'lineage': ['https://openalex.org/I197854408']}], 'topics': [{'id': 'https://openalex.org/T12629', 'display_name': 'Island Studies and Pacific Affairs', 'count': 204, 'subfield': {'id': 'https://openalex.org/subfields/3317', 'display_name': 'Demography'}, 'field': {'id': 'https://openalex.org/fields/33', 'display_name': 'Social Sciences'}, 'domain': {'id': 'https://openalex.org/domains/2', 'display_name': 'Social Sciences'}}, {'id': 'https://openalex.org/T12656', 'display_name': 'Climate Change, Adaptation, Migration', 'count': 64, 'subfield': {'id': 'https://openalex.org/subfields/3312', 'display_name': 'Sociology and Political Science'}, 'field': {'id': 'https://openalex ...
#
# Finished fetching.
# Total authors found and processed: 61
# Total time taken: 1.20 seconds
# 13

# %%
all_authors_list = []

for university_key, authors_list in universities_authors.items():
    if isinstance(authors_list, list):
        for author_doc in authors_list:
            if isinstance(author_doc, dict):
                author_doc_with_uni = author_doc.copy()
                author_doc_with_uni['university_key'] = university_key
                all_authors_list.append(author_doc_with_uni)

if all_authors_list:
    df = pd.DataFrame(all_authors_list)
    parquet_file_path = 'authors_raw_data.parquet'
    try:
        df.to_parquet(parquet_file_path, index=False, engine='pyarrow')
        print(
            f"Successfully saved data for {len(df)} authors to {parquet_file_path}")
    except Exception as e:
        print(f"Error saving data to Parquet: {e}")
else:
    print("No authors data was collected to save")
# Out:
# Successfully saved data for 44381 authors to authors_raw_data.parquet
